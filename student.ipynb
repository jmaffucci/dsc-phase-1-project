# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name:Justin Maffucci
# * Student pace: full time
# * Scheduled project review date/time:
# * Instructor name: James Irving
# * Blog post URL:

# %%
# Your code here - remember to use markdown cells for comments as well!

# %%
'''My Questions:

1. Which genre is most profitable? (Either ROI or Profit)
2. How does runtime affect ratings?
3. Which directors are most successful financially?

'''

# %%
import os, glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

folder = "/Users/justinmaffucci/Desktop/FlatironSchool/Phase1/Project/dsc-phase-1-project/zippedData/"

# %%
files = glob.glob(f"{folder}*.csv*")
## Source: James Irving

# %%
(f"{folder}*.csv*")
### Source: James Irving
# Out:
# '/Users/justinmaffucci/Desktop/FlatironSchool/Phase1/Project/dsc-phase-1-project/zippedData/*.csv*'

# %%
files[0].replace(".csv.gz", '').split('/')[-1].replace('.','_')
### Source: James Irving
# Out:
# 'imdb_title_crew'

# %%
tables = {}
dashes = '---'*25

for file in files:
    table_name = file.replace(".csv.gz", '').split('/')[-1].replace('.','_')
    print(dashes)
    
    print(f"Preview of {table_name}")
    tables[table_name] = pd.read_csv(file)
    display(tables[table_name].head(5))
    print()
    
### Source: James Irving
# Out:
# ---------------------------------------------------------------------------
# Preview of imdb_title_crew
#       tconst                      directors              writers
# 0  tt0285252                      nm0899854            nm0899854
# 1  tt0438973                            NaN  nm0175726,nm1802864
# 2  tt0462036                      nm1940585            nm1940585
# 3  tt0835418                      nm0151540  nm0310087,nm0841532
# 4  tt0878654  nm0089502,nm2291498,nm2292011            nm0284943
# ---------------------------------------------------------------------------
# Preview of tmdb_movies
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                      How to Train Your Dragon           7.7        7610
# 2                                    Iron Man 2           6.8       12368
# 3                                     Toy Story           7.9       10174
# 4                                     Inception           8.3       22186
# ---------------------------------------------------------------------------
# Preview of imdb_title_akas
#     title_id  ordering                                    title region  \
# 0  tt0369610        10                            Джурасик свят     BG
# 1  tt0369610        11                        Jurashikku warudo     JP
# 2  tt0369610        12  Jurassic World: O Mundo dos Dinossauros     BR
# 3  tt0369610        13                  O Mundo dos Dinossauros     BR
# 4  tt0369610        14                           Jurassic World     FR
#
#   language        types   attributes  is_original_title
# 0       bg          NaN          NaN                0.0
# 1      NaN  imdbDisplay          NaN                0.0
# 2      NaN  imdbDisplay          NaN                0.0
# 3      NaN          NaN  short title                0.0
# 4      NaN  imdbDisplay          NaN                0.0
# ---------------------------------------------------------------------------
# Preview of imdb_title_ratings
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21
# ---------------------------------------------------------------------------
# Preview of imdb_name_basics
#       nconst       primary_name  birth_year  death_year  \
# 0  nm0061671  Mary Ellen Bauder         NaN         NaN
# 1  nm0061865       Joseph Bauer         NaN         NaN
# 2  nm0062070         Bruce Baum         NaN         NaN
# 3  nm0062195       Axel Baumann         NaN         NaN
# 4  nm0062798        Pete Baxter         NaN         NaN
#
#                                  primary_profession  \
# 0         miscellaneous,production_manager,producer
# 1        composer,music_department,sound_department
# 2                        miscellaneous,actor,writer
# 3  camera_department,cinematographer,art_department
# 4  production_designer,art_department,set_decorator
#
#                           known_for_titles
# 0  tt0837562,tt2398241,tt0844471,tt0118553
# 1  tt0896534,tt6791238,tt0287072,tt1682940
# 2  tt1470654,tt0363631,tt0104030,tt0102898
# 3  tt0114371,tt2004304,tt1618448,tt1224387
# 4  tt0452644,tt0452692,tt3458030,tt2178256
# ---------------------------------------------------------------------------
# Preview of imdb_title_basics
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy
# ---------------------------------------------------------------------------
# Preview of tn_movie_budgets
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747
# ---------------------------------------------------------------------------
# Preview of bom_movie_gross
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010
# ---------------------------------------------------------------------------
# Preview of imdb_title_principals
#       tconst  ordering     nconst  category       job        characters
# 0  tt0111414         1  nm0246005     actor       NaN       ["The Man"]
# 1  tt0111414         2  nm0398271  director       NaN               NaN
# 2  tt0111414         3  nm3739909  producer  producer               NaN
# 3  tt0323808        10  nm0059247    editor       NaN               NaN
# 4  tt0323808         1  nm3579312   actress       NaN  ["Beth Boothby"]

# %%
### Merge imdb_title_basics with imdb_title_ratings and imdb_name_basics

titles_ratings = pd.merge(tables['imdb_title_basics'], 
                                                 tables['imdb_title_ratings'])

titles_ratings_crew = pd.merge(titles_ratings, tables['imdb_title_crew'])

tables['imdb_name_basics'].rename(columns={'nconst': 'directors'},          
                                                                inplace=True)
titles_ratings_crew = pd.merge(titles_ratings_crew, tables['imdb_name_basics'], 
                                                              on='directors')

### Merge bom_movie_gross with tn_movie_budgets 

financials = pd.merge(tables['bom_movie_gross'], tables['tn_movie_budgets'], 
                                          left_on='title', right_on='movie')

# %%
display(titles_ratings_crew.head(2))
display(financials.head(2))
# Out:
#       tconst                    primary_title   original_title  start_year  \
# 0  tt0063540                        Sunghursh        Sunghursh        2013
# 1  tt0066787  One Day Before the Rainy Season  Ashad Ka Ek Din        2019
#
#    runtime_minutes              genres  averagerating  numvotes  directors  \
# 0            175.0  Action,Crime,Drama            7.0        77  nm0712540
# 1            114.0     Biography,Drama            7.2        43  nm0002411
#
#                                    writers         primary_name  birth_year  \
# 0  nm0023551,nm1194313,nm0347899,nm1391276  Harnam Singh Rawail      1921.0
# 1                                      NaN            Mani Kaul      1944.0
#
#    death_year        primary_profession  \
# 0      2004.0  director,writer,producer
# 1      2011.0     director,writer,actor
#
#                           known_for_titles
# 0  tt0266757,tt0266712,tt0134996,tt0266765
# 1  tt0102515,tt0070009,tt0066514,tt0207626
#          title studio  domestic_gross_x foreign_gross  year  id  release_date  \
# 0  Toy Story 3     BV       415000000.0     652000000  2010  47  Jun 18, 2010
# 1    Inception     WB       292600000.0     535700000  2010  38  Jul 16, 2010
#
#          movie production_budget domestic_gross_y worldwide_gross
# 0  Toy Story 3      $200,000,000     $415,004,880  $1,068,879,522
# 1    Inception      $160,000,000     $292,576,195    $835,524,642

# %%
### Remove redundant and irrelevant columns

titles_ratings_crew.drop(['original_title', 'writers', 'birth_year',
                        'death_year','primary_profession','known_for_titles'],
                                                         axis=1, inplace=True)


financials.drop(['studio', 'domestic_gross_x', 'foreign_gross', 'id',
                'release_date', 'movie','domestic_gross_y'], axis=1,
                                                               inplace=True)


display(financials.head(2))
display(titles_ratings_crew.head(2))
# Out:
#          title  year production_budget worldwide_gross
# 0  Toy Story 3  2010      $200,000,000  $1,068,879,522
# 1    Inception  2010      $160,000,000    $835,524,642
#       tconst                    primary_title  start_year  runtime_minutes  \
# 0  tt0063540                        Sunghursh        2013            175.0
# 1  tt0066787  One Day Before the Rainy Season        2019            114.0
#
#                genres  averagerating  numvotes  directors         primary_name
# 0  Action,Crime,Drama            7.0        77  nm0712540  Harnam Singh Rawail
# 1     Biography,Drama            7.2        43  nm0002411            Mani Kaul

# %%
df = pd.merge(financials, titles_ratings_crew, left_on='title', 
                                                    right_on='primary_title')
display(df.head(2))
# Out:
#          title  year production_budget worldwide_gross     tconst  \
# 0  Toy Story 3  2010      $200,000,000  $1,068,879,522  tt0435761
# 1    Inception  2010      $160,000,000    $835,524,642  tt1375666
#
#   primary_title  start_year  runtime_minutes                      genres  \
# 0   Toy Story 3        2010            103.0  Adventure,Animation,Comedy
# 1     Inception        2010            148.0     Action,Adventure,Sci-Fi
#
#    averagerating  numvotes  directors       primary_name
# 0            8.3    682218  nm0881279        Lee Unkrich
# 1            8.8   1841066  nm0634240  Christopher Nolan

# %%
df.drop(['start_year', 'tconst', 'primary_title','directors'], 
                                                        axis=1, inplace=True)
df.head(2)
# Out:
#          title  year production_budget worldwide_gross  runtime_minutes  \
# 0  Toy Story 3  2010      $200,000,000  $1,068,879,522            103.0
# 1    Inception  2010      $160,000,000    $835,524,642            148.0
#
#                        genres  averagerating  numvotes       primary_name
# 0  Adventure,Animation,Comedy            8.3    682218        Lee Unkrich
# 1     Action,Adventure,Sci-Fi            8.8   1841066  Christopher Nolan

# %%
df.duplicated(subset='title').sum()
# Out:
# 214

# %%
df.drop_duplicates(subset=['title'], inplace=True)
df.duplicated(subset='title').sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# title                0
# year                 0
# production_budget    0
# worldwide_gross      0
# runtime_minutes      3
# genres               1
# averagerating        0
# numvotes             0
# primary_name         0
# dtype: int64

# %%
df.dropna(axis=0, subset=['genres', 'runtime_minutes'], inplace=True)

# %%
display(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1062 entries, 0 to 1279
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              1062 non-null   object
#  1   year               1062 non-null   int64
#  2   production_budget  1062 non-null   object
#  3   worldwide_gross    1062 non-null   object
#  4   runtime_minutes    1062 non-null   float64
#  5   genres             1062 non-null   object
#  6   averagerating      1062 non-null   float64
#  7   numvotes           1062 non-null   int64
#  8   primary_name       1062 non-null   object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 83.0+ KB
# None

# %%
## Remove commas from financial metric columns

df['production_budget'].replace(',','', regex=True, inplace=True)
df['worldwide_gross'].replace(',','', regex=True, inplace=True)

## Remove dollar signs from financial metric columns

df['production_budget'] = df['production_budget'].str.replace('$','')
df['worldwide_gross'] = df['worldwide_gross'].str.replace('$','')

## Change data type to integer for financial columns

df['production_budget'] = df['production_budget'].astype(int)
df['worldwide_gross'] = df['worldwide_gross'].astype(int)

display(df.info())
display(df.head(2))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1062 entries, 0 to 1279
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              1062 non-null   object
#  1   year               1062 non-null   int64
#  2   production_budget  1062 non-null   int64
#  3   worldwide_gross    1062 non-null   int64
#  4   runtime_minutes    1062 non-null   float64
#  5   genres             1062 non-null   object
#  6   averagerating      1062 non-null   float64
#  7   numvotes           1062 non-null   int64
#  8   primary_name       1062 non-null   object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 83.0+ KB
# None
#          title  year  production_budget  worldwide_gross  runtime_minutes  \
# 0  Toy Story 3  2010          200000000       1068879522            103.0
# 1    Inception  2010          160000000        835524642            148.0
#
#                        genres  averagerating  numvotes       primary_name
# 0  Adventure,Animation,Comedy            8.3    682218        Lee Unkrich
# 1     Action,Adventure,Sci-Fi            8.8   1841066  Christopher Nolan

# %%
df['Profit/Loss'] = (df['worldwide_gross'] - df['production_budget'])
df['ROI'] = (df['Profit/Loss'] / df['production_budget'])
df.head(2)
# Out:
#          title  year  production_budget  worldwide_gross  runtime_minutes  \
# 0  Toy Story 3  2010          200000000       1068879522            103.0
# 1    Inception  2010          160000000        835524642            148.0
#
#                        genres  averagerating  numvotes       primary_name  \
# 0  Adventure,Animation,Comedy            8.3    682218        Lee Unkrich
# 1     Action,Adventure,Sci-Fi            8.8   1841066  Christopher Nolan
#
#    Profit/Loss       ROI
# 0    868879522  4.344398
# 1    675524642  4.222029

# %%
df = df[['title', 'year', 'primary_name', 'genres', 'worldwide_gross',
        'production_budget', 'Profit/Loss', 'ROI', 'runtime_minutes',
        'averagerating','numvotes']]
df.columns = ['Title', 'Release Year', 'Director', 'Genres', 'Worldwide Gross',
             'Production Budget', 'Profit/Loss', 'ROI', 'Runtime',
              'Avg. Rating', '# of Votes']
df.head(2)
# Out:
#          Title  Release Year           Director                      Genres  \
# 0  Toy Story 3          2010        Lee Unkrich  Adventure,Animation,Comedy
# 1    Inception          2010  Christopher Nolan     Action,Adventure,Sci-Fi
#
#    Worldwide Gross  Production Budget  Profit/Loss       ROI  Runtime  \
# 0       1068879522          200000000    868879522  4.344398    103.0
# 1        835524642          160000000    675524642  4.222029    148.0
#
#    Avg. Rating  # of Votes
# 0          8.3      682218
# 1          8.8     1841066

# %%
genre_list = []
for string in df['Genres']:
    genre_list.append(string.split(','))
df['Genres'] = genre_list
df.head(2)
# Out:
#          Title  Release Year           Director  \
# 0  Toy Story 3          2010        Lee Unkrich
# 1    Inception          2010  Christopher Nolan
#
#                            Genres  Worldwide Gross  Production Budget  \
# 0  [Adventure, Animation, Comedy]       1068879522          200000000
# 1     [Action, Adventure, Sci-Fi]        835524642          160000000
#
#    Profit/Loss       ROI  Runtime  Avg. Rating  # of Votes
# 0    868879522  4.344398    103.0          8.3      682218
# 1    675524642  4.222029    148.0          8.8     1841066

# %%
genre_ROI = df.explode('Genres').groupby('Genres').median()['ROI']. \
                                                sort_values(ascending=True)
genre_ROI
# Out:
# Genres
# Western       -0.486402
# War           -0.111535
# Music          0.746344
# Crime          0.855759
# Sport          0.915783
# Fantasy        1.097094
# Family         1.131426
# History        1.136088
# Drama          1.173021
# Biography      1.199427
# Action         1.320263
# Romance        1.411546
# Comedy         1.488093
# Documentary    1.512141
# Adventure      1.665471
# Thriller       1.743471
# Animation      1.876877
# Musical        2.124787
# Sci-Fi         2.180978
# Horror         2.702271
# Mystery        2.766204
# Name: ROI, dtype: float64

# %%
sns.axes_style()
# Out:
# {'axes.facecolor': 'white',
#  'axes.edgecolor': 'black',
#  'axes.grid': False,
#  'axes.axisbelow': 'line',
#  'axes.labelcolor': 'black',
#  'figure.facecolor': (1, 1, 1, 0),
#  'grid.color': '#b0b0b0',
#  'grid.linestyle': '-',
#  'text.color': 'black',
#  'xtick.color': 'black',
#  'ytick.color': 'black',
#  'xtick.direction': 'out',
#  'ytick.direction': 'out',
#  'lines.solid_capstyle': 'projecting',
#  'patch.edgecolor': 'black',
#  'patch.force_edgecolor': False,
#  'image.cmap': 'viridis',
#  'font.family': ['sans-serif'],
#  'font.sans-serif': ['DejaVu Sans',
#   'Bitstream Vera Sans',
#   'Computer Modern Sans Serif',
#   'Lucida Grande',
#   'Verdana',
#   'Geneva',
#   'Lucid',
#   'Arial',
#   'Helvetica',
#   'Avant Garde',
#   'sans-serif'],
#  'xtick.bottom': True,
#  'xtick.top': False,
#  'ytick.left': True,
#  'ytick.right': False,
#  'axes.spines.left': True,
#  'axes.spines.bottom': True,
#  'axes.spines.right': True,
#  'axes.spines.top': True}

# %%
sns.set_style('darkgrid')
sns.set_context('notebook')
plt.figure(figsize=(13,8))
sns.barplot(y=genre_ROI.sort_values(ascending=False).index,
                                    x=genre_ROI.sort_values(ascending=False));

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(y=df['Avg. Rating'], x=df['Runtime']);

# %%
genre_df = df.explode('Genres')

# %%
df.head()
# Out:
#                         Title  Release Year           Director  \
# 0                 Toy Story 3          2010        Lee Unkrich
# 1                   Inception          2010  Christopher Nolan
# 2         Shrek Forever After          2010      Mike Mitchell
# 3  The Twilight Saga: Eclipse          2010        David Slade
# 4                  Iron Man 2          2010        Jon Favreau
#
#                            Genres  Worldwide Gross  Production Budget  \
# 0  [Adventure, Animation, Comedy]       1068879522          200000000
# 1     [Action, Adventure, Sci-Fi]        835524642          160000000
# 2  [Adventure, Animation, Comedy]        756244673          165000000
# 3     [Adventure, Drama, Fantasy]        706102828           68000000
# 4     [Action, Adventure, Sci-Fi]        621156389          170000000
#
#    Profit/Loss       ROI  Runtime  Avg. Rating  # of Votes
# 0    868879522  4.344398    103.0          8.3      682218
# 1    675524642  4.222029    148.0          8.8     1841066
# 2    591244673  3.583301     93.0          6.3      167532
# 3    638102828  9.383865    124.0          5.0      211733
# 4    451156389  2.653861    124.0          7.0      657690

# %%
director_ROI = df.groupby('Director').mean()['ROI'].sort_values(ascending=False).head(10)

# %%
director_ROI
# Out:
# Director
# William Brent Bell    100.759490
# Levan Gabriadze        63.364198
# Tod Williams           58.170677
# Jordan Peele           50.073590
# Bradley Parker         41.411721
# Nitesh Tiwari          30.016276
# Lynn Shelton           24.754942
# David F. Sandberg      24.060147
# James Wan              23.410492
# Dan Trachtenberg       20.657284
# Name: ROI, dtype: float64

# %%
plt.figure(figsize=(12,8))
x_labels=director_ROI.index
bar = sns.barplot(x=director_ROI.index, y=director_ROI)
# bar.set_xticklabels=(rotation=30)
plt.xticks(rotation=30, ha='right');

# %%
def rating_category(df):
    if df['Avg. Rating'] < 2.5:
        cat = 'Bust'
    elif (df['Avg. Rating'] >=2.5) & (df['Avg. Rating'] < 5):
        cat = 'Poor'
    elif (df['Avg. Rating'] >= 5) & (df['Avg. Rating'] < 7.5):
        cat = 'Good'
    else:
        cat = 'Excellent'
    return cat

df['Rating Group'] = df.apply(rating_category, axis=1)
